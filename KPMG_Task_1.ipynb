# %% [markdown]
# ## KPMG VIRTUAL INTERNSHIP PROJECT

# %% [markdown]
# ## TASK: 1 - Data Quality Assessment
# Assessment of data quality and completeness in preparation for analysis.
#
# The client provided KPMG with 3 datasets:
#
# 1.Customer Demographic
#
# 2.Customer Addresses
#
# 3.Transactions data in the past 3 months

# %%
# Importing the required libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.ExcelFile(r"C:\Users\jshal\Desktop\KPMG_VI_New_raw_data_update_final .xlsx")
df

# %%
Transactions = pd.read_excel(df, 'Transactions')
NewCustomerList = pd.read_excel(df, 'NewCustomerList')
CustomerDemographic = pd.read_excel(df, 'CustomerDemographic')
CustomerAddress = pd.read_excel(df, 'CustomerAddress')

# %% [markdown]
# ## Transactions Data Set

# %%
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions.tail()
# Out:
#        transaction_id  product_id  customer_id transaction_date  online_order  \
# 19995           19996          51         1018       2017-06-24           1.0
# 19996           19997          41          127       2017-11-09           1.0
# 19997           19998          87         2284       2017-04-14           1.0
# 19998           19999           6         2764       2017-07-03           0.0
# 19999           20000          11         1144       2017-09-22           1.0
#
#       order_status          brand product_line product_class product_size  \
# 19995     Approved     OHM Cycles     Standard          high       medium
# 19996     Approved          Solex         Road        medium       medium
# 19997     Approved     OHM Cycles     Standard        medium       medium
# 19998     Approved     OHM Cycles     Standard          high       medium
# 19999     Approved  Trek Bicycles     Standard        medium        small
#
# ...

# %%
Transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   transaction_id           20000 non-null  int64
#  1   product_id               20000 non-null  int64
#  2   customer_id              20000 non-null  int64
#  3   transaction_date         20000 non-null  datetime64[ns]
#  4   online_order             19640 non-null  float64
#  5   order_status             20000 non-null  object
#  6   brand                    19803 non-null  object
#  7   product_line             19803 non-null  object
#  8   product_class            19803 non-null  object
#  9   product_size             19803 non-null  object
#  10  list_price               20000 non-null  float64
#  11  standard_cost            19803 non-null  float64
#  12  product_first_sold_date  19803 non-null  float64
# ...

# %%
Transactions.shape
# Out:
# (20000, 13)

# %%
Transactions.describe().T
# Out:
#                            count          mean          std       min  \
# transaction_id           20000.0  10000.500000  5773.647028      1.00
# product_id               20000.0     45.364650    30.753590      0.00
# customer_id              20000.0   1738.246050  1011.951046      1.00
# online_order             19640.0      0.500458     0.500013      0.00
# list_price               20000.0   1107.829449   582.825242     12.01
# standard_cost            19803.0    556.046951   405.955660      7.21
# product_first_sold_date  19803.0  38199.776549  2875.201110  33259.00
#
#                               25%       50%       75%       max
# transaction_id            5000.75  10000.50  15000.25  20000.00
# product_id                  18.00     44.00     72.00    100.00
# customer_id                857.75   1736.00   2613.00   5034.00
# online_order                 0.00      1.00      1.00      1.00
# list_price                 575.27   1163.89   1635.30   2091.47
# ...

# %%
Transactions.columns
# Out:
# Index(['transaction_id', 'product_id', 'customer_id', 'transaction_date',
#        'online_order', 'order_status', 'brand', 'product_line',
#        'product_class', 'product_size', 'list_price', 'standard_cost',
#        'product_first_sold_date'],
#       dtype='object')

# %% [markdown]
# ## How are the values in the columns unique?

# %% [markdown]
# ## How many Missing Values are in Each Column?

# %%
Transactions.isnull().sum()

## Online_order, brand product_line, product_Class, product_size, standard_cost, 
## and product_first_slod_date columns have missing values.
# Out:
# transaction_id               0
# product_id                   0
# customer_id                  0
# transaction_date             0
# online_order               360
# order_status                 0
# brand                      197
# product_line               197
# product_class              197
# product_size               197
# list_price                   0
# standard_cost              197
# product_first_sold_date    197
# dtype: int64

# %% [markdown]
# ## How many duplicate values are there?

# %%
Transactions.duplicated().sum()

###There are no duplicate values.
# Out:
# 0

# %% [markdown]
# ## How unique is the Transactions Excel File?

# %%
Transactions.nunique()
# Out:
# transaction_id             20000
# product_id                   101
# customer_id                 3494
# transaction_date             364
# online_order                   2
# order_status                   2
# brand                          6
# product_line                   4
# product_class                  3
# product_size                   3
# list_price                   296
# standard_cost                103
# product_first_sold_date      100
# dtype: int64

# %%
Transactions["brand"].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
Transactions.head()
# Out:
#    transaction_id  product_id  customer_id transaction_date  online_order  \
# 0               1           2         2950       2017-02-25           0.0
# 1               2           3         3120       2017-05-21           1.0
# 2               3          37          402       2017-10-16           0.0
# 3               4          88         3135       2017-08-31           0.0
# 4               5          78          787       2017-10-01           1.0
#
#   order_status           brand product_line product_class product_size  \
# 0     Approved           Solex     Standard        medium       medium
# 1     Approved   Trek Bicycles     Standard        medium        large
# 2     Approved      OHM Cycles     Standard           low       medium
# 3     Approved  Norco Bicycles     Standard        medium       medium
# 4     Approved  Giant Bicycles     Standard        medium        large
#
#    list_price  standard_cost  product_first_sold_date
# ...

# %%
Transactions["product_size"].value_counts()
# Out:
# medium    12990
# large      3976
# small      2837
# Name: product_size, dtype: int64

# %%
Transactions["product_line"].value_counts()
# Out:
# Standard    14176
# Road         3970
# Touring      1234
# Mountain      423
# Name: product_line, dtype: int64

# %%
Transactions["brand"].value_counts()
# Out:
# Solex             4253
# Giant Bicycles    3312
# WeareA2B          3295
# OHM Cycles        3043
# Trek Bicycles     2990
# Norco Bicycles    2910
# Name: brand, dtype: int64

# %%
Transactions["order_status"].value_counts()
# Out:
# Approved     19821
# Cancelled      179
# Name: order_status, dtype: int64

# %%
Transactions["product_class"].value_counts()
# Out:
# medium    13826
# high       3013
# low        2964
# Name: product_class, dtype: int64

# %%
# Explore the column: [product_first_sold_date]

Transactions['product_first_sold_date']
# Out:
# 0        41245.0
# 1        41701.0
# 2        36361.0
# 3        36145.0
# 4        42226.0
#           ...
# 19995    37823.0
# 19996    35560.0
# 19997    40410.0
# 19998    38216.0
# 19999    36334.0
# Name: product_first_sold_date, Length: 20000, dtype: float64

# %% [markdown]
# ## Convert date column from integer to datetime. There is also the to_datetime() function of the pandas library to convert timestamps into datetime objects. Since our timestamp’s integer part is in seconds, we will set the time unit as ‘s’.

# %%
#convert date column from integer to datetime
Transactions['product_first_sold_date'] = pd.to_datetime(Transactions['product_first_sold_date'], unit='h')
Transactions['product_first_sold_date'].head(50)
# Out:
# 0    1974-09-15 13:00:00
# 1    1974-10-04 13:00:00
# 2    1974-02-24 01:00:00
# 3    1974-02-15 01:00:00
# 4    1974-10-26 10:00:00
# 5    1974-06-15 07:00:00
# 6    1973-11-24 13:00:00
# 7    1974-07-22 03:00:00
# 8    1973-10-25 23:00:00
# 9    1974-05-12 08:00:00
# 10   1974-08-27 08:00:00
# 11   1974-10-24 04:00:00
# 12   1973-12-09 15:00:00
# 13   1973-12-12 02:00:00
# 14   1974-05-11 09:00:00
# 15   1974-04-28 01:00:00
# 16   1974-05-11 22:00:00
# 17   1973-11-13 00:00:00
# 18   1974-07-22 03:00:00
# 19   1974-04-05 17:00:00
# 20   1974-02-22 22:00:00
# 21   1974-02-24 01:00:00
# 22   1974-10-23 01:00:00
# 23   1974-11-02 20:00:00
# 24   1973-11-20 23:00:00
# 25   1974-10-23 01:00:00
# 26   1974-09-07 07:00:00
# 27   1974-11-09 08:00:00
# 28   1974-11-15 14:00:00
# 29   1974-10-13 18:00:00
# 30   1974-04-14 03:00:00
# 31   1974-11-14 16:00:00
# 32   1974-11-02 20:00:00
# 33   1974-06-13 15:00:00
# 34   1974-05-30 07:00:00
# 35   1974-04-28 02:00:00
# 36   1973-12-29 04:00:00
# ...

# %%
Transactions['product_first_sold_date'].tail()
# Out:
# 19995   1974-04-25 23:00:00
# 19996   1974-01-21 16:00:00
# 19997   1974-08-11 18:00:00
# 19998   1974-05-12 08:00:00
# 19999   1974-02-22 22:00:00
# Name: product_first_sold_date, dtype: datetime64[ns]

# %% [raw]
# On the actual excel sheet, it shows the [product_first_sold_date] column as raw sequence of numbers.
# After the column was changed from integer to datetime, all of the transactions seem to say that
# all transactions took place on the same day and time.

# %% [markdown]
# ## Exploring "New Customes List Data Set"

# %%
NewCustomerList.head(20)
# Out:
#    first_name     last_name  gender  past_3_years_bike_related_purchases  \
# 0     Chickie       Brister    Male                                   86
# 1       Morly        Genery    Male                                   69
# 2     Ardelis     Forrester  Female                                   10
# 3      Lucine         Stutt  Female                                   64
# 4     Melinda        Hadlee  Female                                   34
# 5       Druci       Brandli  Female                                   39
# 6    Rutledge         Hallt    Male                                   23
# 7      Nancie          Vian  Female                                   74
# 8        Duff     Karlowicz    Male                                   50
# 9     Barthel        Docket    Male                                   72
# 10   Rockwell        Matson    Male                                   94
# 11    Wheeler       Winward    Male                                   48
# ...

# %%
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %% [markdown]
# ## Line 16-through 20 gives us unnamed columns which are unnecessary. So it would be beneficial to drop them.

# %%
#Dropping the unnamed columns
NewCustomerList.drop(['Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
       'Unnamed: 19', 'Unnamed: 20'], axis=1, inplace=True)
NewCustomerList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   first_name                           1000 non-null   object
#  1   last_name                            971 non-null    object
#  2   gender                               1000 non-null   object
#  3   past_3_years_bike_related_purchases  1000 non-null   int64
#  4   DOB                                  983 non-null    datetime64[ns]
#  5   job_title                            894 non-null    object
#  6   job_industry_category                835 non-null    object
#  7   wealth_segment                       1000 non-null   object
#  8   deceased_indicator                   1000 non-null   object
#  9   owns_car                             1000 non-null   object
#  10  tenure                               1000 non-null   int64
# ...

# %% [markdown]
# ## How many Null Values in the NewCustomerList excel wife?

# %%
NewCustomerList.isnull().sum()
# Out:
# first_name                               0
# last_name                               29
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     17
# job_title                              106
# job_industry_category                  165
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                   0
# address                                  0
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# Rank                                     0
# Value                                    0
# dtype: int64

# %% [markdown]
# ## The columns: last_name, DOB, job_title, and job_industry_category have missing values. Based on analysis, these missing values can be treated by: dropping, inputting mean values, or using mode values.

# %% [markdown]
# ## Check for the Duplicated values

# %%
NewCustomerList.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### How unique is this excel file?

# %%
NewCustomerList.nunique()
# Out:
# first_name                              940
# last_name                               961
# gender                                    3
# past_3_years_bike_related_purchases     100
# DOB                                     958
# job_title                               184
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        1
# owns_car                                  2
# tenure                                   23
# address                                1000
# postcode                                522
# state                                     3
# country                                   1
# property_valuation                       12
# Rank                                    324
# Value                                   324
# dtype: int64

# %%
NewCustomerList.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Rank', 'Value'],
#       dtype='object')

# %%
NewCustomerList.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#          DOB                   job_title job_industry_category  \
# 0 1957-07-12             General Manager         Manufacturing
# 1 1970-03-22         Structural Engineer              Property
# 2 1974-08-28      Senior Cost Accountant    Financial Services
# 3 1979-01-28  Account Representative III         Manufacturing
# 4 1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  tenure              address  \
# 0      Mass Customer                  N      Yes      14     45 Shopko Center
# ...

# %%
NewCustomerList["gender"].value_counts()
# Out:
# Female    513
# Male      470
# U          17
# Name: gender, dtype: int64

# %% [markdown]
# ### "u" is not defined clearly. There are 17 of such cases.

# %%
NewCustomerList[NewCustomerList.gender == "U"]
# Out:
#     first_name    last_name gender  past_3_years_bike_related_purchases DOB  \
# 59       Normy     Goodinge      U                                    5 NaT
# 226      Hatti     Carletti      U                                   35 NaT
# 324   Rozamond       Turtle      U                                   69 NaT
# 358      Tamas      Swatman      U                                   65 NaT
# 360      Tracy   Andrejevic      U                                   71 NaT
# 374     Agneta      McAmish      U                                   66 NaT
# 434      Gregg      Aimeric      U                                   52 NaT
# 439      Johna       Bunker      U                                   93 NaT
# 574    Harlene         Nono      U                                   69 NaT
# 598   Gerianne       Kaysor      U                                   15 NaT
# 664     Chicky      Sinclar      U                                   43 NaT
# ...

# %%
NewCustomerList["job_industry_category"].value_counts()
# Out:
# Financial Services    203
# Manufacturing         199
# Health                152
# Retail                 78
# Property               64
# IT                     51
# Entertainment          37
# Argiculture            26
# Telecommunications     25
# Name: job_industry_category, dtype: int64

# %% [markdown]
# ### Financial Service is the job sector with the most people

# %%
NewCustomerList['wealth_segment'].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
NewCustomerList['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %%
NewCustomerList['owns_car'].value_counts()
# Out:
# No     507
# Yes    493
# Name: owns_car, dtype: int64

# %%
NewCustomerList['deceased_indicator'].value_counts()
# Out:
# N    1000
# Name: deceased_indicator, dtype: int64

# %%
NewCustomerList["wealth_segment"].value_counts()
# Out:
# Mass Customer        508
# High Net Worth       251
# Affluent Customer    241
# Name: wealth_segment, dtype: int64

# %%
NewCustomerList['state'].value_counts()
# Out:
# NSW    506
# VIC    266
# QLD    228
# Name: state, dtype: int64

# %% [markdown]
# ### State is not defined clearly. The three categories need more speciification in their names

# %% [markdown]
# # Customer Demographic Data Set

# %%
CustomerDemographic.head(20)
# Out:
#     customer_id      first_name  last_name  gender  \
# 0             1         Laraine  Medendorp       F
# 1             2             Eli    Bockman    Male
# 2             3           Arlin     Dearle    Male
# 3             4          Talbot        NaN    Male
# 4             5  Sheila-kathryn     Calton  Female
# 5             6            Curr  Duckhouse    Male
# 6             7            Fina     Merali  Female
# 7             8             Rod      Inder    Male
# 8             9            Mala       Lind  Female
# 9            10        Fiorenze    Birdall  Female
# 10           11           Uriah     Bisatt    Male
# 11           12         Sawyere   Flattman    Male
# 12           13        Gabriele   Norcross    Male
# 13           14        Rayshell   Kitteman  Female
# 14           15          Erroll     Radage    Male
# 15           16          Harlin       Parr    Male
# 16           17           Heath    Faraday    Male
# ...

# %%
CustomerDemographic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 13 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4000 non-null   int64
#  1   first_name                           4000 non-null   object
#  2   last_name                            3875 non-null   object
#  3   gender                               4000 non-null   object
#  4   past_3_years_bike_related_purchases  4000 non-null   int64
#  5   DOB                                  3913 non-null   datetime64[ns]
#  6   job_title                            3494 non-null   object
#  7   job_industry_category                3344 non-null   object
#  8   wealth_segment                       4000 non-null   object
#  9   deceased_indicator                   4000 non-null   object
#  10  default                              3698 non-null   object
# ...

# %%
#Checking for null values
CustomerDemographic.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              125
# gender                                   0
# past_3_years_bike_related_purchases      0
# DOB                                     87
# job_title                              506
# job_industry_category                  656
# wealth_segment                           0
# deceased_indicator                       0
# default                                302
# owns_car                                 0
# tenure                                  87
# dtype: int64

# %% [markdown]
# ## The columns: 'last_name', DOB, job_Title, job_industry_category, default, and tenure have missing values.

# %%
CustomerDemographic.duplicated().sum()
# Out:
# 0

# %%
#Checking for uniqueness of each column
CustomerDemographic.nunique()
# Out:
# customer_id                            4000
# first_name                             3139
# last_name                              3725
# gender                                    6
# past_3_years_bike_related_purchases     100
# DOB                                    3448
# job_title                               195
# job_industry_category                     9
# wealth_segment                            3
# deceased_indicator                        2
# default                                  90
# owns_car                                  2
# tenure                                   22
# dtype: int64

# %%
CustomerDemographic.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'default', 'owns_car', 'tenure'],
#       dtype='object')

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female    2037
# Male      1872
# U           88
# F            1
# Femal        1
# M            1
# Name: gender, dtype: int64

# %% [markdown]
# ### The "U", "F", "Femal", and "M"  can be dropeed because its useless or placed in the appropriate M or F columns.

# %%
CustomerDemographic['gender'] = CustomerDemographic['gender'].replace('F','Female').replace('M','Male').replace('Femal','Female').replace('U','Unspecified')

# %%
CustomerDemographic['gender'].value_counts()
# Out:
# Female         2039
# Male           1873
# Unspecified      88
# Name: gender, dtype: int64

# %%
CustomerDemographic['job_industry_category'].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                602
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: job_industry_category, dtype: int64

# %%
CustomerDemographic['wealth_segment'].value_counts()
# Out:
# Mass Customer        2000
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segment, dtype: int64

# %%
CustomerDemographic['deceased_indicator'].value_counts()
# Out:
# N    3998
# Y       2
# Name: deceased_indicator, dtype: int64

# %%
CustomerDemographic['default'].value_counts()
# Out:
# 100                                       113
# 1                                         112
# -1                                        111
# -100                                       99
# Ù¡Ù¢Ù£                                     53
#                                          ...
# testâ testâ«                               31
# /dev/null; touch /tmp/blns.fail ; echo     30
# âªâªtestâª                                 29
# ì¸ëë°í ë¥´                                 27
# ,ãã»:*:ã»ãâ( â» Ï â» )ãã»:*:ã»ãâ           25
# Name: default, Length: 90, dtype: int64

# %% [markdown]
# ### This entire column is unecessary as it has so many useless values.

# %%
CustomerDemographic = CustomerDemographic.drop('default', axis=1)
CustomerDemographic.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            3           Arlin     Dearle    Male
# 3            4          Talbot        NaN    Male
# 4            5  Sheila-kathryn     Calton  Female
#
#    past_3_years_bike_related_purchases        DOB               job_title  \
# 0                                   93 1953-10-12     Executive Secretary
# 1                                   81 1980-12-16  Administrative Officer
# 2                                   61 1954-01-20      Recruiting Manager
# 3                                   33 1961-10-03                     NaN
# 4                                   56 1977-05-13           Senior Editor
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  tenure
# 0                Health      Mass Customer                  N      Yes    11.0
# ...

# %%
CustomerDemographic["owns_car"].value_counts()
# Out:
# Yes    2024
# No     1976
# Name: owns_car, dtype: int64

# %%
CustomerDemographic['tenure'].value_counts()
# Out:
# 7.0     235
# 5.0     228
# 11.0    221
# 10.0    218
# 16.0    215
# 8.0     211
# 18.0    208
# 12.0    202
# 9.0     200
# 14.0    200
# 6.0     192
# 13.0    191
# 4.0     191
# 17.0    182
# 15.0    179
# 1.0     166
# 3.0     160
# 19.0    159
# 2.0     150
# 20.0     96
# 22.0     55
# 21.0     54
# Name: tenure, dtype: int64

# %% [markdown]
# ## Exploring Customer Address Data Set

# %%
CustomerAddress.head(5)
# Out:
#    customer_id              address  postcode            state    country  \
# 0            1   060 Morning Avenue      2016  New South Wales  Australia
# 1            2  6 Meadow Vale Court      2153  New South Wales  Australia
# 2            4   0 Holy Cross Court      4211              QLD  Australia
# 3            5  17979 Del Mar Point      2448  New South Wales  Australia
# 4            6     9 Oakridge Court      3216              VIC  Australia
#
#    property_valuation
# 0                  10
# 1                  10
# 2                   9
# 3                   4
# 4                   9

# %%
CustomerAddress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         3999 non-null   int64
#  1   address             3999 non-null   object
#  2   postcode            3999 non-null   int64
#  3   state               3999 non-null   object
#  4   country             3999 non-null   object
#  5   property_valuation  3999 non-null   int64
# dtypes: int64(3), object(3)
# memory usage: 187.6+ KB

# %%
#Checking for null values.
CustomerAddress.isnull().sum()
# Out:
# customer_id           0
# address               0
# postcode              0
# state                 0
# country               0
# property_valuation    0
# dtype: int64

# %%
#Checking for uniqueness of each column
CustomerAddress.nunique()
# Out:
# customer_id           3999
# address               3996
# postcode               873
# state                    5
# country                  1
# property_valuation      12
# dtype: int64

# %%
CustomerAddress['postcode'].value_counts()
# Out:
# 2170    31
# 2155    30
# 2145    30
# 2153    29
# 3977    26
#         ..
# 3808     1
# 3114     1
# 4721     1
# 4799     1
# 3089     1
# Name: postcode, Length: 873, dtype: int64

# %%
CustomerAddress['state'].value_counts()
# Out:
# NSW                2054
# VIC                 939
# QLD                 838
# New South Wales      86
# Victoria             82
# Name: state, dtype: int64

# %%
CustomerAddress['country'].value_counts()
# Out:
# Australia    3999
# Name: country, dtype: int64

# %%
CustomerAddress['property_valuation'].value_counts()
# Out:
# 9     647
# 8     646
# 10    577
# 7     493
# 11    281
# 6     238
# 5     225
# 4     214
# 12    195
# 3     186
# 1     154
# 2     143
# Name: property_valuation, dtype: int64

# %% [markdown]
# ## All the columns have accurate and necessary information. Nothing is not ordinary.
